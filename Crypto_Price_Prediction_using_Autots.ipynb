# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashi-sharma/Crypto-Price-Prediction-using-Autots/blob/main/Crypto_Price_Prediction_using_Autots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=730)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('BTC-USD', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 50 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 10.4 MB/s
# ...
#      |████████████████████████████████| 128 kB 33.1 MB/s
# ...
#      |████████████████████████████████| 112 kB 62.8 MB/s
# ...
#      |████████████████████████████████| 110 kB 72.9 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.4 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
data.head()
# Out:
#         Date          Open          High           Low         Close  \
# 0 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 1 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
# 2 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 3 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 4 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
#
#       Adj Close       Volume
# 0  28840.953125  51287442704
# 1  29001.720703  46754964848
# 2  29374.152344  40730301359
# 3  32127.267578  67865420765
# 4  32782.023438  78665235202

# %%
data.tail()
# Out:
#           Date          Open          High           Low         Close  \
# 725 2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 726 2022-12-26  16842.250000  16920.123047  16812.369141  16919.804688
# 727 2022-12-27  16919.291016  16959.845703  16642.072266  16717.173828
# 728 2022-12-28  16716.400391  16768.169922  16497.556641  16552.572266
# 729 2022-12-29  16552.322266  16651.755859  16508.683594  16642.341797
#
#         Adj Close       Volume
# 725  16841.986328  11656379938
# 726  16919.804688  11886957804
# 727  16717.173828  15748580239
# 728  16552.572266  17005713920
# 729  16642.341797  14472237479

# %%
data.shape
# Out:
# (730, 7)

# %%
import plotly.graph_objects as go
figure = go.Figure(data=[go.Candlestick(x=data["Date"],
                                        open=data["Open"], 
                                        high=data["High"],
                                        low=data["Low"], 
                                        close=data["Close"])])
figure.update_layout(title = "Bitcoin Price Analysis", 
                     xaxis_rangeslider_visible=False)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
correlation = data.corr()
print(correlation["Close"].sort_values(ascending=False))
# Out:
# Close        1.000000
# Adj Close    1.000000
# High         0.997258
# Low          0.996824
# Open         0.993853
# Volume       0.256471
# Name: Close, dtype: float64

# %% [markdown]
# Predicting the future prices of cryptocurrency is based on the problem of Time series analysis. The AutoTS library in Python is one of the best libraries for time series analysis. So here I will be using the AutoTS library to predict the bitcoin prices for the next 30 days:

# %%
# !pip install azureml
# !pip install autots
from autots import AutoTS
model = AutoTS(forecast_length=30, frequency='infer', ensemble='simple')
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 674 kB 5.2 MB/s
# ...
# Inferred frequency is: D
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model ARIMA in generation 0 of 10
# Model Number: 3 with model ARIMA in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model AverageValueNaive in generation 0 of 10
# Model Number: 6 with model AverageValueNaive in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# Model Number: 8 with model DatepartRegression in generation 0 of 10
# Model Number: 9 with model DatepartRegression in generation 0 of 10
# /usr/local/lib/python3.8/dist-packages/sklearn/svm/_base.py:1206: ConvergenceWarning:
#
# ...

# %%
forecast
# Out:
#                    Close
# 2022-12-30  17136.325527
# 2022-12-31  17259.942731
# 2023-01-01  17342.249060
# 2023-01-02  17353.749149
# 2023-01-03  17441.085643
# 2023-01-04  17349.768277
# 2023-01-05  17218.794902
# 2023-01-06  17088.716726
# 2023-01-07  16834.638099
# 2023-01-08  16452.569944
# 2023-01-09  16161.225559
# 2023-01-10  15873.015580
# 2023-01-11  15535.678818
# 2023-01-12  15189.055037
# 2023-01-13  14944.135306
# 2023-01-14  14686.702280
# 2023-01-15  14371.066130
# 2023-01-16  14091.202012
# 2023-01-17  13827.591040
# 2023-01-18  13664.695605
# 2023-01-19  13594.314076
# 2023-01-20  13492.310273
# 2023-01-21  13437.763747
# 2023-01-22  13389.482515
# 2023-01-23  13351.636994
# 2023-01-24  13324.693210
# 2023-01-25  13369.237303
# 2023-01-26  13435.268753
# 2023-01-27  13502.645271
# 2023-01-28  13614.561446
